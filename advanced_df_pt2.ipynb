# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import numpy as np
import pandas as pd
from sqlalchemy import text, create_engine
from pydataset import data

from env import get_connection

# %% [markdown]
# Let's read in the users and roles tables from the join_example_db.

# %%
engine = create_engine(get_connection('join_example_db'))

# %%
users_query = '''
              SELECT *
              FROM users
              '''

roles_query = '''
              SELECT *
              FROM roles
              '''

# %%
users = pd.read_sql(text(users_query), engine.connect())
roles = pd.read_sql(text(roles_query), engine.connect())

# %% [markdown]
# Let's try joining our two dataframes together with pd.concat()!

# %%
users
# Out:
#    id   name              email  role_id
# 0   1    bob    bob@example.com      1.0
# 1   2    joe    joe@example.com      2.0
# 2   3  sally  sally@example.com      3.0
# 3   4   adam   adam@example.com      3.0
# 4   5   jane   jane@example.com      NaN
# 5   6   mike   mike@example.com      NaN

# %%
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
pd.concat([users,roles])
# Out:
#    id       name              email  role_id
# 0   1        bob    bob@example.com      1.0
# 1   2        joe    joe@example.com      2.0
# 2   3      sally  sally@example.com      3.0
# 3   4       adam   adam@example.com      3.0
# 4   5       jane   jane@example.com      NaN
# 5   6       mike   mike@example.com      NaN
# 0   1      admin                NaN      NaN
# 1   2     author                NaN      NaN
# 2   3   reviewer                NaN      NaN
# 3   4  commenter                NaN      NaN

# %% [markdown]
# Ok, now how about calling the .merge() method off one of our tables!

# %%
pd.concat([users,roles],axis=1)
# Out:
#    id   name              email  role_id   id       name
# 0   1    bob    bob@example.com      1.0  1.0      admin
# 1   2    joe    joe@example.com      2.0  2.0     author
# 2   3  sally  sally@example.com      3.0  3.0   reviewer
# 3   4   adam   adam@example.com      3.0  4.0  commenter
# 4   5   jane   jane@example.com      NaN  NaN        NaN
# 5   6   mike   mike@example.com      NaN  NaN        NaN

# %%
users.merge(roles,how='inner',left_on='role_id',right_on='id')
# Out:
#    id_x name_x              email  role_id  id_y    name_y
# 0     1    bob    bob@example.com      1.0     1     admin
# 1     2    joe    joe@example.com      2.0     2    author
# 2     3  sally  sally@example.com      3.0     3  reviewer
# 3     4   adam   adam@example.com      3.0     3  reviewer

# %% [markdown]
# Let's read in the mpg dataset and create a new binary column for automatic/manual transmission.

# %%
mpg = data('mpg')
mpg['auto_or_man'] = np.where(mpg['trans'].str.startswith('a'), 'auto', 'manual')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#   auto_or_man
# 1        auto
# 2      manual
# 3      manual
# 4        auto
# 5        auto

# %% [markdown]
# Let's do a crosstab of two categorical variables, the drive type and the transmission type.

# %%
pd.crosstab(mpg['drv'],mpg['auto_or_man'])
# Out:
# auto_or_man  auto  manual
# drv
# 4              75      28
# f              65      41
# r              17       8

# %% [markdown]
# We can set normalize equal to True, to return the proportion of all cars each combination represents.

# %%
pd.crosstab(mpg['drv'],mpg['auto_or_man'],normalize = True)
# Out:
# auto_or_man      auto    manual
# drv
# 4            0.320513  0.119658
# f            0.277778  0.175214
# r            0.072650  0.034188

# %% [markdown]
# A pivot table will look similar to a crosstab.
#
# We specify which two categorical variables will be along the axes.
#
# The index argument specifies the index and the columns argument specifies the column.
#
# We will pass in a third argument, values, to return the mean of that column.
#
# If we don't want the mean, we can specify a fourth argument (aggfunc) for a different aggregate function.

# %%
mpg.pivot_table(index='drv',columns='auto_or_man',values = 'hwy')
# Out:
# auto_or_man       auto     manual
# drv
# 4            18.586667  20.750000
# f            27.292308  29.536585
# r            19.529412  24.125000

# %%
mpg.pivot_table(index='drv',columns='auto_or_man',values = 'hwy',aggfunc = 'max')
# Out:
# auto_or_man  auto  manual
# drv
# 4              27      28
# f              41      44
# r              25      26

# %% [markdown]
# The map method will use a dictionary to map existing values to desired ones.

# %%
drv_dict = {'4': 'four-wheel drive',
            'f': 'front-wheel drive',
            'r': 'rear-wheel drive'}

# %%
mpg['drv'] = mpg.drv.map(drv_dict)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans                drv  \
# 1           audi      a4    1.8  1999    4    auto(l5)  front-wheel drive
# 2           audi      a4    1.8  1999    4  manual(m5)  front-wheel drive
# 3           audi      a4    2.0  2008    4  manual(m6)  front-wheel drive
# 4           audi      a4    2.0  2008    4    auto(av)  front-wheel drive
# 5           audi      a4    2.8  1999    6    auto(l5)  front-wheel drive
# ..           ...     ...    ...   ...  ...         ...                ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)  front-wheel drive
# 231   volkswagen  passat    2.0  2008    4  manual(m6)  front-wheel drive
# 232   volkswagen  passat    2.8  1999    6    auto(l5)  front-wheel drive
# 233   volkswagen  passat    2.8  1999    6  manual(m5)  front-wheel drive
# 234   volkswagen  passat    3.6  2008    6    auto(s6)  front-wheel drive
#
#      cty  hwy fl    class auto_or_man
# 1     18   29  p  compact        auto
# 2     21   29  p  compact      manual
# 3     20   31  p  compact      manual
# 4     21   30  p  compact        auto
# 5     16   26  p  compact        auto
# ..   ...  ... ..      ...         ...
# 230   19   28  p  midsize        auto
# 231   21   29  p  midsize      manual
# 232   16   26  p  midsize        auto
# 233   18   26  p  midsize      manual
# 234   17   26  p  midsize        auto
#
# [234 rows x 12 columns]

# %% [markdown]
# We can transpose dataframes by saying .T.

# %%
mpg.T
# Out:
#                             1                  2                  3    \
# manufacturer               audi               audi               audi
# model                        a4                 a4                 a4
# displ                       1.8                1.8                2.0
# year                       1999               1999               2008
# cyl                           4                  4                  4
# trans                  auto(l5)         manual(m5)         manual(m6)
# drv           front-wheel drive  front-wheel drive  front-wheel drive
# cty                          18                 21                 20
# hwy                          29                 29                 31
# fl                            p                  p                  p
# class                   compact            compact            compact
# auto_or_man                auto             manual             manual
#
#                             4                  5                  6    \
# manufacturer               audi               audi               audi
# model                        a4                 a4                 a4
# displ                       2.0                2.8                2.8
# year                       2008               1999               1999
# cyl                           4                  6                  6
# trans                  auto(av)           auto(l5)         manual(m5)
# drv           front-wheel drive  front-wheel drive  front-wheel drive
# cty                          21                 16                 18
# hwy                          30                 26                 26
# fl                            p                  p                  p
# class                   compact            compact            compact
# auto_or_man                auto               auto             manual
#
#                             7                 8                 9    \
# manufacturer               audi              audi              audi
# model                        a4        a4 quattro        a4 quattro
# displ                       3.1               1.8               1.8
# year                       2008              1999              1999
# cyl                           6                 4                 4
# trans                  auto(av)        manual(m5)          auto(l5)
# drv           front-wheel drive  four-wheel drive  four-wheel drive
# cty                          18                18                16
# hwy                          27                26                25
# fl                            p                 p                 p
# class                   compact           compact           compact
# auto_or_man                auto            manual              auto
#
#                            10   ...                225                226  \
# manufacturer              audi  ...         volkswagen         volkswagen
# model               a4 quattro  ...         new beetle         new beetle
# displ                      2.0  ...                2.0                2.5
# year                      2008  ...               1999               2008
# cyl                          4  ...                  4                  5
# trans               manual(m6)  ...           auto(l4)         manual(m5)
# drv           four-wheel drive  ...  front-wheel drive  front-wheel drive
# cty                         20  ...                 19                 20
# hwy                         28  ...                 26                 28
# fl                           p  ...                  r                  r
# class                  compact  ...         subcompact         subcompact
# auto_or_man             manual  ...               auto             manual
#
#                             227                228                229  \
# manufacturer         volkswagen         volkswagen         volkswagen
# model                new beetle             passat             passat
# displ                       2.5                1.8                1.8
# year                       2008               1999               1999
# cyl                           5                  4                  4
# trans                  auto(s6)         manual(m5)           auto(l5)
# drv           front-wheel drive  front-wheel drive  front-wheel drive
# cty                          20                 21                 18
# hwy                          29                 29                 29
# fl                            r                  p                  p
# class                subcompact            midsize            midsize
# auto_or_man                auto             manual               auto
#
#                             230                231                232  \
# manufacturer         volkswagen         volkswagen         volkswagen
# model                    passat             passat             passat
# displ                       2.0                2.0                2.8
# year                       2008               2008               1999
# cyl                           4                  4                  6
# trans                  auto(s6)         manual(m6)           auto(l5)
# drv           front-wheel drive  front-wheel drive  front-wheel drive
# cty                          19                 21                 16
# hwy                          28                 29                 26
# fl                            p                  p                  p
# class                   midsize            midsize            midsize
# auto_or_man                auto             manual               auto
#
#                             233                234
# manufacturer         volkswagen         volkswagen
# model                    passat             passat
# displ                       2.8                3.6
# year                       1999               2008
# cyl                           6                  6
# trans                manual(m5)           auto(s6)
# drv           front-wheel drive  front-wheel drive
# cty                          18                 17
# hwy                          26                 26
# fl                            p                  p
# class                   midsize            midsize
# auto_or_man              manual               auto
#
# [12 rows x 234 columns]
