# %%
import numpy as np
import pandas as pd
from pydataset import data
import math

import matplotlib.pyplot as plt

# %% [markdown]
# 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# * Title your chart "Big O Notation"
# * Label your x axis "Elements"
# * Label your y axis "Operations"
# * Label your curves or make a legend for the curves
# * Use LaTex notation where possible
#
# Curves to graph
#
# * y = 0n + 1        a
# * y = log(n)        b
# * y = n             c
# * y = n * log(n)    d
# * y = n ** 2        e
# * y = 2 ** n        f
# * y = n!            g
# * y = n**n          h

# %%
x = list(range(1,11))

ad = {'x':x,
      'y':[(n * 0) + 1 for n in x]}
a = pd.DataFrame(ad)

bd = {'x':x,
      'y':[math.log(n) for n in x]}
b = pd.DataFrame(bd)

cd = {'x':x,
      'y':[n for n in x]}
c = pd.DataFrame(cd)

dd = {'x':x,
      'y':[n ** 2   for n in x]}
d = pd.DataFrame(dd)

ed = {'x':x,
      'y':[n * math.log(n) for n in x]}
e = pd.DataFrame(ed)

fd = {'x':x,
      'y':[2 ** n for n in x]}
f = pd.DataFrame(fd)

gd = {'x':x,
      'y':[math.factorial(n) for n in x]}
g = pd.DataFrame(gd)

hd = {'x':x,
      'y':[n**n for n in x]}
h = pd.DataFrame(hd)

# %%
plt.figure(figsize=(8,8))
plt.xticks(range(0,11))
plt.ylim(0,100)
plt.xlim(0,10)
plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.grid(True, ls = '--')

plt.plot(a.x,a.y,label='O(1)')
plt.plot(b.x,b.y,label='O(log n)')
plt.plot(c.x,c.y,label='O(n)')
plt.plot(d.x,d.y,label='O(n log n)')
plt.plot(e.x,e.y,label='O(n^2)')
plt.plot(f.x,f.y,label='O(2^n)')
plt.plot(g.x,g.y,label='O(n!)')
plt.plot(h.x,h.y,label='O(n^n)')


plt.legend()
plt.show()
